# %% [markdown]
# ### Tensor Foundations

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cu128

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.11.0+cu128
# 12.8
# True

# %%
import numpy as np
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
print(f"Torch Version = {torch.__version__}")
# Out:
# Torch Version = 2.11.0+cu128

# %%
import torch

print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA GeForce RTX 3050 A Laptop GPU

# %% [markdown]
# ### Scalar tensors

# %%
tensor0d = torch.tensor(5.56)
print(f"Data Type :{tensor0d.dtype}")

print(tensor0d)
# Out:
# Data Type :torch.float32
# tensor(5.5600)

# %%
tensor0d=torch.tensor(6)
print(tensor0d)
print(f"Data Type :{tensor0d.dtype}")
tensor0d.ndim
# Out:
# tensor(6)
# Data Type :torch.int64
# 0

# %%
tensor0d.shape
# Out:
# torch.Size([])

# %% [markdown]
# ### Vector - 1D tensor

# %%
tensor1d = torch.tensor([10,20,30,40,50,60])
print(tensor1d)
print(tensor1d.shape)
print(f"size of tensor : {tensor0d.size()}")
print(f"Device on which tensor is running : {tensor1d.device}")
tensor1d.ndim
# Out:
# tensor([10, 20, 30, 40, 50, 60])
# torch.Size([6])
# size of tensor : torch.Size([])
# Device on which tensor is running : cpu
# 1

# %% [markdown]
# ### Metrix 2D tensors

# %%
tensor2d = torch.tensor([[10,20],[30,40]])
print(tensor2d)
tensor2d.shape
tensor2d.ndim
# Out:
# tensor([[10, 20],
#         [30, 40]])
# 2
