# %%
import torch
import numpy as np

# %%
t1 = torch.tensor([10,20,30,40,50,60])
t2 = torch.tensor([1,2,3,4,5,6])

# %% [markdown]
# ### Add

# %%
t1+t2
# Out:
# tensor([11, 22, 33, 44, 55, 66])

# %%
t2.add(t1)
# Out:
# tensor([11, 22, 33, 44, 55, 66])

# %% [markdown]
# ### Sub

# %%
t2-t1
# Out:
# tensor([ -9, -18, -27, -36, -45, -54])

# %%
t1.sub(t2)
# Out:
# tensor([ 9, 18, 27, 36, 45, 54])

# %% [markdown]
# ### Mul

# %%
t1*t2
# Out:
# tensor([ 10,  40,  90, 160, 250, 360])

# %% [markdown]
# ### Div

# %%
t2/t1
# Out:
# tensor([0.1000, 0.1000, 0.1000, 0.1000, 0.1000, 0.1000])

# %% [markdown]
# ### Power

# %%
t1.pow(3)
# Out:
# tensor([  1000,   8000,  27000,  64000, 125000, 216000])

# %% [markdown]
# ### Square root

# %%
t1.sqrt()
# Out:
# tensor([3.1623, 4.4721, 5.4772, 6.3246, 7.0711, 7.7460])

# %% [markdown]
# ### reciprocol sequare root

# %%
t1.rsqrt()
# Out:
# tensor([0.3162, 0.2236, 0.1826, 0.1581, 0.1414, 0.1291])

# %% [markdown]
# ### Exponential

# %%
t1.exp()
# Out:
# tensor([2.2026e+04, 4.8517e+08, 1.0686e+13, 2.3539e+17, 5.1847e+21, 1.1420e+26])

# %% [markdown]
# ### Natural Log

# %%
t1.log()
# Out:
# tensor([2.3026, 2.9957, 3.4012, 3.6889, 3.9120, 4.0943])

# %% [markdown]
# ### Base Log 10

# %%
t1.log10()
# Out:
# tensor([1.0000, 1.3010, 1.4771, 1.6021, 1.6990, 1.7782])

# %% [markdown]
# ### Base Log 2

# %%
t1.log2()
# Out:
# tensor([3.3219, 4.3219, 4.9069, 5.3219, 5.6439, 5.9069])

# %% [markdown]
# ### Absolute Values

# %%
t1.abs()
# Out:
# tensor([10, 20, 30, 40, 50, 60])

# %%
t1.neg()
# Out:
# tensor([-10, -20, -30, -40, -50, -60])
