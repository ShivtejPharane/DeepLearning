# %%
import numpy as np
import torch
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### prepare the dataset for the stock prices

# %%
# Downdload the Apple stock prices from 2020-01-01 to 2026-01-01
response = yf.download('AAPL',start='2020-01-01',end='2026-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
prices = response['Close'].values
print(prices.shape)
print(prices.ndim)
# Out:
# (1508, 1)
# 2

# %%
# convert the dataset 2D->1D
prices = prices.squeeze(1)

# %%
print(prices.ndim)
# Out:
# 1

# %%
print(prices.max())
print(prices.min())
# Out:
# 285.4131164550781
# 54.11701965332031

# %% [markdown]
# ### Data Preprocessing

# %%
# Scale the Data Using the Normalization
# (price - min(price)) / (max(price) - min(price))
minimum_price = prices.min()
maximum_price = prices.max()

prices_normalized = (prices - minimum_price) / (maximum_price - minimum_price)

# %%
print(prices_normalized)
# Out:
# [0.07849035 0.07545259 0.07791825 ... 0.94640532 0.94347318 0.93821293]

# %%
combined_data = [prices,prices_normalized]
plt.boxplot(combined_data,labels=['Before Normalization','After Normalization'],patch_artist=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_11508\1054826592.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(combined_data,labels=['Before Normalization','After Normalization'],patch_artist=True)
# {'whiskers': [<matplotlib.lines.Line2D at 0x122beac3770>,
#   <matplotlib.lines.Line2D at 0x122beac38c0>,
#   <matplotlib.lines.Line2D at 0x122bed54050>,
#   <matplotlib.lines.Line2D at 0x122bed541a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x122beac3a10>,
#   <matplotlib.lines.Line2D at 0x122beac3b60>,
#   <matplotlib.lines.Line2D at 0x122bed542f0>,
#   <matplotlib.lines.Line2D at 0x122bed54440>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x122beac3380>,
#   <matplotlib.patches.PathPatch at 0x122bea00e10>],
#  'medians': [<matplotlib.lines.Line2D at 0x122beac3cb0>,
#   <matplotlib.lines.Line2D at 0x122bed54590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x122beac3e00>,
#   <matplotlib.lines.Line2D at 0x122bed546e0>],
#  'means': []}

# %% [markdown]
# ### Genrate the Data

# %%
# sequence length used to genrate x and y
SEQUENCE_LENGTH = 20

# %%
x = []
y = []

# %%
for index in range(len(prices_normalized)-SEQUENCE_LENGTH):
    x.append(prices_normalized[index:index+SEQUENCE_LENGTH])
    y.append(prices_normalized[index+SEQUENCE_LENGTH])
x = np.array(x)
y = np.array(y)
# convert the x and y to tensors
x = torch.tensor(x,dtype=torch.float32)
y = torch.tensor(y,dtype=torch.float32)

# %%
print(f"Shape of input : {x.shape} Shape of ouput {y.shape}")
# Out:
# Shape of input : torch.Size([1488, 20]) Shape of ouput torch.Size([1488])

# %% [markdown]
# ### DEfine the Model

# %%
x = x.unsqueeze(-1)  # shape becomes torch.Size([983, 20, 1])
y = y.unsqueeze(-1)  # shape becomes torch.Size([983, 1])
class StockPricePrediction(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.rnn = torch.nn.RNN(
            input_size = 1,
            hidden_size = 40,
            batch_first = True
        )
        self.linear = torch.nn.Linear(40,1)
    def forward(self,x):
        output,hidden= self.rnn(x)
        hidden = hidden[-1]
        output = self.linear(hidden)
        return output

# %% [markdown]
# ### Create the model and define the Hyperparameters

# %%
model = StockPricePrediction()

# %% [markdown]
# ### Define the Hyper parameters

# %%
epochs = 500
loss_function = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.01)

# %% [markdown]
# ### Training Loop

# %%
device=''
if torch.cuda.is_available():
    device='cuda'
else:
    device='cpu'

# %%
x=x.to(device)
y=y.to(device)
model=model.to(device)

# %%
total_loss = 0
for epoch in range(epochs):
    prediction = model(x)
    loss = loss_function(prediction,y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if (epoch+1) %50 ==0:
        print(f"epoch : {epoch+1}, loss : {loss}")
# Out:
# epoch : 50, loss : 0.0002640834136400372
# epoch : 100, loss : 0.00025200098752975464
# epoch : 150, loss : 0.00024274423776660115
# epoch : 200, loss : 0.00023505357967223972
# epoch : 250, loss : 0.00022784114116802812
# epoch : 300, loss : 0.0002212057588621974
# epoch : 350, loss : 0.00021517640561796725
# epoch : 400, loss : 0.00020974774088244885
# epoch : 450, loss : 0.00020489416783675551
# epoch : 500, loss : 0.00020057911751791835

# %% [markdown]
# ### Test the model by predicting next day stock price

# %%
# get the last sequence only
last_sequence = prices_normalized[-SEQUENCE_LENGTH:]
last_sequence = (torch.tensor(last_sequence,dtype=torch.float32)).to(device)

# %%
last_sequence.unsqueeze_(0).unsqueeze_(-1)
last_sequence.ndim
# Out:
# 3

# %%
with torch.no_grad():
    prediction = model(last_sequence)
    print(prediction)
# Out:
# tensor([[0.9356]], device='cuda:0')

# %%
print(prices[-5:])
# Out:
# [273.06671143 272.65786743 273.01687622 272.33868408 271.12200928]

# %% [markdown]
# ### Plot the Prediction

# %%
prediction_numpy=[]
with torch.no_grad():
    for i in x:
        i = i.to(device)
        i.unsqueeze_(0)
        prediction = model(i)
        prediction_numpy.append(prediction.cpu())

# %%
len(prediction_numpy)
# Out:
# 1488

# %%
# Convert predictions back to original stock price scale
predictions_scaled = np.array(prediction_numpy).squeeze() * (maximum_price - minimum_price) + minimum_price

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(prices[20:], label='Actual Prices')
plt.plot(predictions_scaled, color='red', label='Predicted Prices')
plt.xlabel('Time Step')
plt.ylabel('Price')
plt.legend()
plt.show()
