# %%
import numpy as np

# %%
sentence = "I love machine learning nlp and Python"

# %% [markdown]
# ### Text Preprocesing

# %%
from nltk.tokenize import word_tokenize
words = word_tokenize(sentence)
print(words)
# Out:
# ['I', 'love', 'machine', 'learning', 'nlp', 'and', 'Python']

# %%
all_words = [word.lower() for word in words]

# %%
all_words
# Out:
# ['i', 'love', 'machine', 'learning', 'nlp', 'and', 'python']

# %%
def genrate_ngram(words,n):
    grams = []
    for i in range(len(words)-n+1):
        grams.append(words[i:i+n])
